# %% [markdown]
# # Tarang v11 — Lead I Native Training Pipeline
#
# **Objective:** Eliminate the Lead I/Lead II domain mismatch by training the CNN natively on Lead I data (PTB-XL + CPSC2018). Validate arrhythmia detection (AFib, VT) and DSP (NLMS) on dedicated external databases.
#
# ## Strict Constraints (Non-Negotiable)
#
# 1. **CNN Training Data:** PTB-XL (Lead I) + CPSC2018 (Lead I) ONLY. MIT-BIH, AFDB, INCART, etc., are strictly excluded from CNN training.
# 2. **5-Label Target System:** To solve record-level label noise, beats are categorized as `N_clean`, `V_clean`, `S_clean`, `NOISE`, or `AMBIGUOUS`. Only `_clean` beats are used for training.
# 3. **Patient-Wise Split:** PTB-XL `strat_fold` (1-8 train, 9 val, 10 test) + CPSC patient-wise split. Zero patient overlap enforced.
# 4. **Anti-Aliasing:** 500Hz → 250Hz via `scipy.signal.resample_poly` (polyphase FIR anti-alias). Naive striding is forbidden.
# 5. **Edge Beat Handling:** Beats lacking 65 pre/post samples or 2-beat RR history are dropped. No zero-padding of RR features.
# 6. **Model Size Honesty:** Architecture is unchanged. Raw weights ~26KB (Gate ~8KB, SV ~18KB). TFLite framework overhead brings total flash footprint to ~71KB.
# 7. **3-Number Evaluation:**
#    - Number 1 (Primary): Held-out Lead I test split (PTB-XL/CPSC).
#    - Number 2 (Generalization): INCART (Lead I).
#    - Number 3 (Legacy): MIT-BIH (Lead II — expect drop, document mismatch).
# 8. **Clinical Engine Validation:**
#    - AFib: PhysioNet 2017 Challenge (true single-lead wearable) + LTAFDB (sustained episodes).
#    - VT: CUDB (Ventricular Tachyarrhythmia).
#    - NLMS: NSTDB (simulated adaptive filter SNR test — not IMU-based, but provides literature-comparable noise reduction metric).
#
# ## Datasets Required
#
# Ensure these are available in `BASE_DIR`:
# - `PTB-XL/` (HR*.hea, HR*.mat, ptbxl_database.csv)
# - `CPSC2018/` (A*.hea, A*.mat, REFERENCE.csv)
# - `incartdb/` (External validation)
# - `mit-bih-arrhythmia-database-1.0.0/` (Legacy cross-check)
# - `AFDB/` (Engine validation)
# - `LTAFDB/` (Engine validation)
# - `CUDB/` (Engine validation)
# - `NSTDB/` (DSP validation)
# - `Challenge2017/` (training2017/ folder with A*.mat, A*.hea, REFERENCES.csv)

# %% [markdown]
# ## 2. Reproducibility Setup

# %%
# ── Section 2: Reproducibility Setup ─────────────────────────────────────────
import os, sys, json, glob, time, uuid, random, platform, shutil, zipfile, warnings, hashlib, ast, re
from pathlib import Path
from datetime import datetime
from collections import Counter, deque
from dataclasses import dataclass
from typing import Optional, List, Dict, Tuple

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from scipy.signal import resample_poly, butter, filtfilt
from scipy.io import loadmat
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (confusion_matrix, f1_score, classification_report,
                              precision_recall_fscore_support, accuracy_score)
from sklearn.utils import class_weight

import wfdb
import wfdb.processing

import tensorflow as tf
from tensorflow.keras import regularizers, layers, Model, Input

warnings.filterwarnings('ignore')

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer): return int(obj)
        if isinstance(obj, np.floating): return float(obj)
        if isinstance(obj, np.ndarray): return obj.tolist()
        if isinstance(obj, (set, frozenset)): return list(obj)
        return super().default(obj)

def jdumps(*args, **kwargs):
    return json.dump(*args, cls=NpEncoder, **kwargs)

SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
rng = np.random.default_rng(SEED)

RUN_ID = datetime.now().strftime("%Y%m%d_%H%M%S") + "_" + uuid.uuid4().hex[:8]
ROOT_OUT = Path("artifacts/v11_leadi_runs") / RUN_ID
ROOT_OUT.mkdir(parents=True, exist_ok=False)

SUBDIRS = ["00_config", "01_data_manifest", "02_features", "03_splits", "04_models_float",
           "05_models_tflite", "06_metrics", "07_figures", "08_engine_eval", "09_firmware_export", "10_reports"]
for d in SUBDIRS: (ROOT_OUT / d).mkdir(parents=True, exist_ok=False)

ENV_INFO = {'python': sys.version.split()[0], 'numpy': np.__version__, 'tensorflow': tf.__version__, 'wfdb': wfdb.__version__}
with open(ROOT_OUT / "00_config" / "environment.json", "w", encoding='utf-8') as f: jdumps(ENV_INFO, f, indent=2)

print(f"RUN_ID: {RUN_ID}")
print(f"ROOT_OUT: {ROOT_OUT.resolve()}")
# Out:
# RUN_ID: 20260713_233009_eeb329c1
# ROOT_OUT: C:\MMD Public\Hackathons\Team Ocelleon\projects\tarang-ml\artifacts\v11_leadi_runs\20260713_233009_eeb329c1

# %% [markdown]
# ## 3. Configuration

# %%
# ── Section 3: Configuration ─────────────────────────────────────────────────
BASE_DIR = r'C:/MMD Public/Hackathons/Team Ocelleon/dataset'

DATASET_PATHS = {
    'ptbxl': os.path.join(BASE_DIR, 'PTB-XL'),
    'cpsc': os.path.join(BASE_DIR, 'CPSC2018'),
    'incart': os.path.join(BASE_DIR, 'incartdb'),
    'mitdb': os.path.join(BASE_DIR, 'mit-bih-arrhythmia-database-1.0.0'),
    'svdb': os.path.join(BASE_DIR, 'mit-bih-supraventricular-arrhythmia-database-1.0.0'),
    'afdb': os.path.join(BASE_DIR, 'AFDB'),
    'ltafdb': os.path.join(BASE_DIR, 'LTAFDB'),
    'cudb': os.path.join(BASE_DIR, 'CUDB'),
    'nstdb': os.path.join(BASE_DIR, 'NSTDB'),
    'p2017': os.path.join(BASE_DIR, 'Challenge2017'),
}

CONFIG = {
    "run_id": RUN_ID, "seed": SEED,
    "target_fs": 250, "window_len": 130, "pre_r": 65, "post_r": 65,
    "rr_features": 7, "classes": ["N", "S", "V"],
    "cleaning_threshold": 0.85,
    "n_share_target": 0.35, "aug_max_copies": 10,
    "epochs": 60, "batch_size": 256, "learning_rate": 1e-3,
    "early_stop_patience": 12, "reduce_lr_patience": 5,
    "reduce_lr_factor": 0.5, "reduce_lr_min": 1e-6,
    "l2_reg": 1e-4, "dropout_rr": 0.20, "dropout_merge": 0.35,
    "model_size_note": "Raw weights ~26KB. TFLite framework overhead brings total flash footprint to ~71KB."
}

with open(ROOT_OUT / "00_config" / "config.json", "w", encoding='utf-8') as f: jdumps(CONFIG, f, indent=2)

# Verify datasets — use recursive glob for nested structures (e.g. Challenge2017/training/A06/)
for name, path in DATASET_PATHS.items():
    exists = os.path.isdir(path)
    # Search recursively (** matches any number of directories)
    n_hea = len(glob.glob(os.path.join(path, '**', '*.hea'), recursive=True)) if exists else 0
    print(f"{name:<10} {'OK' if exists and n_hea > 0 else 'MISSING':>8} ({n_hea} .hea)")
# Out:
# ptbxl            OK (21837 .hea)
# cpsc             OK (6877 .hea)
# incart           OK (75 .hea)
# mitdb            OK (71 .hea)
# svdb             OK (78 .hea)
# afdb             OK (25 .hea)
# ltafdb           OK (84 .hea)
# cudb             OK (35 .hea)
# nstdb            OK (15 .hea)
# p2017            OK (8828 .hea)

# %% [markdown]
# ## 4. Lead I Preprocessing & Anti-Aliasing
#
# **Critical Fix:** 500Hz → 250Hz downsampling uses `scipy.signal.resample_poly` (polyphase FIR anti-alias filter). Naive striding is forbidden as it folds high-frequency noise back into the passband.

# %%
# ── Section 4: Preprocessing Helpers ─────────────────────────────────────────
def rolling_window_normalize(signal, fs, window_seconds=30.0):
    ws = int(window_seconds * fs)
    s = pd.Series(signal.astype(np.float64))
    roll = s.rolling(window=ws, min_periods=1)
    mean = roll.mean(); std = roll.std(ddof=0).fillna(0).clip(lower=1e-8)
    return ((s - mean) / std).values.astype(np.float32)

def bandpass_filter(signal, fs, low=0.5, high=40.0, order=2):
    nyq = 0.5 * fs
    b, a = butter(order, [low/nyq, high/nyq], btype='band')
    return filtfilt(b, a, signal).astype(np.float32)

def resample_to_target(signal, fs_source, fs_target=250):
    # Constraint 4: Polyphase anti-alias filter enforced
    if fs_source == fs_target: return signal.astype(np.float32)
    from math import gcd
    g = gcd(int(fs_source), int(fs_target))
    up, down = int(fs_target)//g, int(fs_source)//g
    return resample_poly(signal, up=up, down=down).astype(np.float32)

def preprocess_signal(raw_signal, fs_source, fs_target=250):
    sig = resample_to_target(raw_signal, fs_source, fs_target)
    sig = np.nan_to_num(sig, nan=0.0, posinf=0.0, neginf=0.0)
    sig = sig - np.mean(sig)
    sig = bandpass_filter(sig, fs_target)
    sig = rolling_window_normalize(sig, fs_target)
    return sig
print("Preprocessing helpers defined (Anti-Aliasing enforced).")
# Out:
# Preprocessing helpers defined (Anti-Aliasing enforced).

# %% [markdown]
# ## 5. 5-Label Target System & Beat Extraction
#
# **Constraint 2 & 5:** To solve record-level label noise, beats are categorized into 5 labels. Edge beats lacking 65 pre/post samples or 2-beat RR history are dropped (no zero-padding).
#
# - `N_clean`: NSR records, normal RR
# - `V_clean`: PVC records, wide QRS, premature
# - `S_clean`: PAC records, RR ratio < 0.85 (strict)
# - `NOISE`: XQRS failed or saturated signal
# - `AMBIGUOUS`: PVC/PAC records that don't meet strict criteria (dropped)

# %%
# ── Section 5: Beat Extraction & 5-Label System ──────────────────────────────
WINDOW = CONFIG['window_len']; HALF = WINDOW // 2

def compute_rr_features(peaks_sec, i):
    # Constraint 5: Requires 2-beat lookahead. Drops first/last 2 beats of record.
    n = len(peaks_sec)
    if i < 2 or i >= n - 2: return None # Insufficient history/lookahead
    prev_idx = max(0, i-1); next_idx = min(n-1, i+1)
    rr_prev = peaks_sec[i] - peaks_sec[prev_idx]
    rr_next = peaks_sec[next_idx] - peaks_sec[i]
    lo, hi = max(0, i-2), min(n-1, i+2)
    local = np.diff(peaks_sec[lo:hi+1]).astype(np.float32)
    rr_mean_5 = float(np.mean(local)) if len(local) > 0 else rr_prev
    rr_std_5  = float(np.std(local))  if len(local) > 0 else 0.0
    prematurity = rr_prev / max(rr_mean_5, 1e-4)
    post_pause  = rr_next / max(rr_mean_5, 1e-4)
    local_hr = 60000.0 / max(rr_mean_5 * 1000.0, 1e-4)
    return np.array([rr_prev*1000, rr_next*1000, rr_mean_5*1000, rr_std_5*1000,
                      prematurity, post_pause, local_hr], dtype=np.float32)

def detect_rpeaks(ecg, fs=250):
    try:
        xqrs = wfdb.processing.XQRS(sig=ecg.astype(np.float64), fs=fs)
        xqrs.detect()
        return np.asarray(xqrs.qrs_inds, dtype=np.int64)
    except: return np.array([], dtype=np.int64)

def extract_beats_5label(signal, peaks, record_label):
    # record_label: 'N', 'V', or 'S' (derived from PTB-XL/CPSC metadata)
    peaks_sec = peaks / 250.0
    beats, rrs, labels = [], [], []
    
    for i, peak in enumerate(peaks):
        # Constraint 5: Drop edge beats
        if peak - HALF < 0 or peak + HALF >= len(signal): continue
        rr_feat = compute_rr_features(peaks_sec, i)
        if rr_feat is None: continue
            
        prematurity = float(rr_feat[4])
        is_premature = prematurity < CONFIG['cleaning_threshold']
        
        # 5-Label Logic
        beat = signal[peak-HALF:peak+HALF].reshape(-1, 1).astype(np.float32)
        beat_label = 'AMBIGUOUS' # Default
        
        if record_label == 'N':
            if not is_premature: beat_label = 'N_clean'
        elif record_label == 'V':
            # V_clean if premature, else ambiguous (could be normal beat in a PVC record)
            if is_premature: beat_label = 'V_clean'
        elif record_label == 'S':
            # S_clean if strictly premature, else ambiguous
            if is_premature: beat_label = 'S_clean'
            
        beats.append(beat); rrs.append(rr_feat); labels.append(beat_label)
        
    return beats, rrs, labels

print("5-Label extraction system defined.")
print("  - Edge beats dropped (no zero-padding)")
print("  - 2-beat RR lookahead enforced")
# Out:
# 5-Label extraction system defined.
#   - Edge beats dropped (no zero-padding)
#   - 2-beat RR lookahead enforced

# %% [markdown]
# ## 6. Patient-Wise Data Loading (PTB-XL + CPSC2018)
#
# **Constraint 1 & 3:** Load only PTB-XL and CPSC2018 for CNN training. Split strictly by patient using PTB-XL `strat_fold` and CPSC record IDs.

# %%
# ── Section 6: PTB-XL + CPSC Data Loading (Flat Layout / SNOMED-CT) ──────────
all_beats, all_rrs, all_labels, all_meta = [], [], [], []

# SNOMED-CT codes
SNOMED_PAC = {'284470004'}
SNOMED_PVC = {'427172004', '17338001'}
SNOMED_NSR = {'426783006'}

def parse_hea_dx(hea_path):
    """Parse #Dx: line from .hea file. Returns set of SNOMED codes."""
    import re
    try:
        with open(hea_path, encoding='utf-8', errors='ignore') as f:
            for line in f:
                stripped = line.strip().lower()
                if stripped.startswith('#dx:') or stripped.startswith('# dx:'):
                    colon_idx = line.find(':')
                    if colon_idx == -1: continue
                    codes_str = line[colon_idx + 1:].strip()
                    codes = re.split(r'[ ,\t]+', codes_str)
                    return set(c.strip() for c in codes if c.strip())
    except: pass
    return set()

def get_snomed_label(dx_codes):
    """Returns 'N', 'S', 'V', or None based on SNOMED codes."""
    has_pac = bool(dx_codes & SNOMED_PAC)
    has_pvc = bool(dx_codes & SNOMED_PVC)
    if has_pac and has_pvc: return None
    if has_pac: return 'S'
    if has_pvc: return 'V'
    if dx_codes & SNOMED_NSR: return 'N'
    return None

# --- PTB-XL (Flat Layout: HR*.hea with #Dx: SNOMED codes) ---
ptbxl_path = DATASET_PATHS['ptbxl']
hr_files = sorted(glob.glob(os.path.join(ptbxl_path, 'HR*.hea')))
if hr_files:
    # Load ptbxl_database.csv for real patient_id and strat_fold
    ptbxl_csv = os.path.join(ptbxl_path, 'ptbxl_database.csv')
    ptbxl_fold_map = {}
    if os.path.isfile(ptbxl_csv):
        df_ptbxl = pd.read_csv(ptbxl_csv, index_col='ecg_id')
        for ecg_id, row in df_ptbxl.iterrows():
            ptbxl_fold_map[ecg_id] = (int(row['strat_fold']), row['patient_id'])
        print(f"  Loaded ptbxl_database.csv: {len(ptbxl_fold_map)} records")
    else:
        print("  ⚠ ptbxl_database.csv not found, using hash split")
    
    def ptbxl_split(rec_basename):
        try:
            ecg_num = int(rec_basename.lstrip('HRLR').lstrip('0') or '0')
        except:
            ecg_num = 0
        if ecg_num in ptbxl_fold_map:
            fold, patient_id = ptbxl_fold_map[ecg_num]
        else:
            fold = (hash(rec_basename) % 10) + 1
            patient_id = rec_basename
        if fold <= 8: return 'train', fold, patient_id
        elif fold == 9: return 'val', fold, patient_id
        else: return 'test', fold, patient_id

    ptbxl_stats = {'attempted': 0, 'no_peaks': 0, 'failed': 0, 'skipped_label': 0}
    for hf in hr_files:
        ptbxl_stats['attempted'] += 1
        basename = os.path.splitext(os.path.basename(hf))[0]
        dx_codes = parse_hea_dx(hf)
        rec_label = get_snomed_label(dx_codes)
        if rec_label is None:
            ptbxl_stats['skipped_label'] += 1
            continue
        path = os.path.join(ptbxl_path, basename)
        try:
            rec = wfdb.rdrecord(path)
            sig = preprocess_signal(rec.p_signal[:, 0], rec.fs)
            peaks = detect_rpeaks(sig)
            if len(peaks) < 5:
                ptbxl_stats['no_peaks'] += 1
                continue
            b, r, l = extract_beats_5label(sig, peaks, rec_label)
            split, fold, patient_id = ptbxl_split(basename)
            for i in range(len(b)):
                all_beats.append(b[i]); all_rrs.append(r[i]); all_labels.append(l[i])
                all_meta.append({'source': 'PTB-XL', 'patient_id': patient_id,
                                 'record_id': basename, 'split': split, 'fold': fold})
        except Exception:
            ptbxl_stats['failed'] += 1
    print(f"PTB-XL loaded: {len([m for m in all_meta if m['source']=='PTB-XL'])} beats")
    print(f"  Stats: attempted={ptbxl_stats['attempted']}, no_peaks={ptbxl_stats['no_peaks']}, "
          f"failed={ptbxl_stats['failed']}, skipped_label={ptbxl_stats['skipped_label']}")
else:
    print("PTB-XL HR*.hea files not found.")

# --- CPSC2018 (Flat Layout: A*.hea with #Dx: SNOMED codes) ---
cpsc_path = DATASET_PATHS['cpsc']
cpsc_hea_files = sorted(glob.glob(os.path.join(cpsc_path, 'A*.hea')))
if cpsc_hea_files:
    def cpsc_split(rec_id):
        h = int(hashlib.md5(str(rec_id).encode()).hexdigest(), 16) % 100
        if h < 70: return 'train'
        elif h < 85: return 'val'
        else: return 'test'
    cpsc_stats = {'attempted': 0, 'no_peaks': 0, 'failed': 0, 'skipped_label': 0}
    for hf in cpsc_hea_files:
        cpsc_stats['attempted'] += 1
        basename = os.path.splitext(os.path.basename(hf))[0]
        dx_codes = parse_hea_dx(hf)
        rec_label = get_snomed_label(dx_codes)
        if rec_label is None:
            cpsc_stats['skipped_label'] += 1
            continue
        path = os.path.join(cpsc_path, basename)
        try:
            rec = wfdb.rdrecord(path)
            sig = preprocess_signal(rec.p_signal[:, 0], rec.fs)
            peaks = detect_rpeaks(sig)
            if len(peaks) < 5:
                cpsc_stats['no_peaks'] += 1
                continue
            b, r, l = extract_beats_5label(sig, peaks, rec_label)
            split = cpsc_split(basename)
            for i in range(len(b)):
                all_beats.append(b[i]); all_rrs.append(r[i]); all_labels.append(l[i])
                all_meta.append({'source': 'CPSC', 'patient_id': basename,
                                 'record_id': basename, 'split': split, 'fold': -1})
        except Exception:
            cpsc_stats['failed'] += 1
    print(f"CPSC2018 loaded: {len([m for m in all_meta if m['source']=='CPSC'])} beats")
    print(f"  Stats: attempted={cpsc_stats['attempted']}, no_peaks={cpsc_stats['no_peaks']}, "
          f"failed={cpsc_stats['failed']}, skipped_label={cpsc_stats['skipped_label']}")
else:
    print("CPSC2018 A*.hea files not found.")

# Convert to arrays
X_ecg = np.stack(all_beats) if all_beats else np.empty((0, WINDOW, 1), dtype=np.float32)
X_rr  = np.stack(all_rrs) if all_rrs else np.empty((0, 7), dtype=np.float32)
y_labels = np.array(all_labels, dtype=object)
meta_df = pd.DataFrame(all_meta)

# Drop NOISE and AMBIGUOUS beats
clean_mask = np.isin(y_labels, ['N_clean', 'V_clean', 'S_clean'])
X_ecg = X_ecg[clean_mask]; X_rr = X_rr[clean_mask]; y_labels = y_labels[clean_mask]
meta_df = meta_df[clean_mask].reset_index(drop=True)

le = LabelEncoder()
le.fit(['N_clean', 'S_clean', 'V_clean'])
y_class = le.transform(y_labels)

np.savez_compressed(ROOT_OUT / "02_features" / "beat_features.npz", X_ecg=X_ecg, X_rr=X_rr, y_class=y_class)
meta_df.to_csv(ROOT_OUT / "02_features" / "beat_metadata.csv", index=False, encoding='utf-8')

print(f"\nTotal clean beats extracted: {len(X_ecg)}")
print(f"Class distribution (clean): {Counter(y_labels)}")
print(f"Split distribution: {Counter(meta_df['split'])}")

# Patient-wise split leakage check
train_pids = set(meta_df[meta_df['split']=='train']['patient_id'])
val_pids   = set(meta_df[meta_df['split']=='val']['patient_id'])
test_pids  = set(meta_df[meta_df['split']=='test']['patient_id'])
assert train_pids.isdisjoint(val_pids), "LEAKAGE: train/val patient overlap!"
assert train_pids.isdisjoint(test_pids), "LEAKAGE: train/test patient overlap!"
assert val_pids.isdisjoint(test_pids), "LEAKAGE: val/test patient overlap!"
print("Patient-wise split leakage check: PASSED")
# Out:
#   ⚠ ptbxl_database.csv not found, using hash split
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# ...
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# CPSC2018 loaded: 26872 beats
#   Stats: attempted=6877, no_peaks=2, failed=0, skipped_label=5343
#
# Total clean beats extracted: 152028
# Class distribution (clean): Counter({'N_clean': 149921, 'S_clean': 2107})
# Split distribution: Counter({'train': 120566, 'val': 16221, 'test': 15241})
# Patient-wise split leakage check: PASSED

# %% [markdown]
# ## 7. Class Balancing
#
# **Constraint:** Augment minority classes (S, V) to match majority (N) using standard v9.3 augmentation (shift, amplitude, noise).

# %%
# ── Section 7: Class Balancing ───────────────────────────────────────────────
train_mask = (meta_df['split'] == 'train').values
val_mask   = (meta_df['split'] == 'val').values
test_mask  = (meta_df['split'] == 'test').values

# FIX: Print class counts per split to verify S beats exist
class_names = {0: 'N', 1: 'S', 2: 'V'}
for split_name, mask in [('train', train_mask), ('val', val_mask), ('test', test_mask)]:
    counts = Counter(y_class[mask])
    print(f"{split_name} class distribution: N={counts.get(0,0)}, S={counts.get(1,0)}, V={counts.get(2,0)}")
    if counts.get(1, 0) == 0:
        print(f"  ⚠ WARNING: {split_name} has ZERO S beats! S F1 will be 0.")
        print(f"    Consider relaxing cleaning_threshold (currently {CONFIG['cleaning_threshold']})")

rr_scaler = StandardScaler().fit(X_rr[train_mask])
X_rr_norm = rr_scaler.transform(X_rr).astype(np.float32)
with open(ROOT_OUT / "00_config" / "rr_scaler.json", "w", encoding='utf-8') as f:
    jdumps({'mean': rr_scaler.mean_.tolist(), 'scale': rr_scaler.scale_.tolist()}, f, indent=2)

def augment_batch(X_c, X_rr_c, class_name, n_copies, seed=SEED):
    # FIX: ECG-only augmentation. Do NOT modify standardized RR features.
    rng_aug = np.random.default_rng(seed); n = len(X_c)
    if n == 0 or n_copies == 0: return np.empty((0,)+X_c.shape[1:], dtype=np.float32), np.empty((0,)+X_rr_c.shape[1:], dtype=np.float32)
    out_X = np.repeat(X_c, n_copies, axis=0)
    out_rr = np.repeat(X_rr_c, n_copies, axis=0).copy()  # Copy, don't modify
    shift = rng_aug.integers(-3, 4, size=len(out_X)); out_X_aug = np.empty_like(out_X)
    for i, s in enumerate(shift):
        if s > 0: out_X_aug[i, :-s] = out_X[i, s:]; out_X_aug[i, -s:] = out_X[i, -1:]
        elif s < 0: out_X_aug[i, -s:] = out_X[i, :s]; out_X_aug[i, :-s] = out_X[i, :1]
        else: out_X_aug[i] = out_X[i]
    amp = rng_aug.uniform(0.85, 1.15, size=(len(out_X), 1, 1)).astype(np.float32)
    out_X_aug *= amp; out_X_aug += rng_aug.normal(0, 0.02, size=out_X_aug.shape).astype(np.float32)
    # RR features left unchanged - they are standardized z-scores, not raw ms
    return out_X_aug, out_rr

y_train = y_class[train_mask]
n_per = Counter(y_train)
target_sv = max(n_per.get(1,0), n_per.get(2,0))
target_n = int(target_sv * (CONFIG['n_share_target'] / (1 - CONFIG['n_share_target'])))

X_train, X_rr_train = X_ecg[train_mask], X_rr_norm[train_mask]
bal_X, bal_rr, bal_y = [X_train], [X_rr_train], [y_train]

for ci, cn in enumerate(['N', 'S', 'V']):
    n_have = n_per.get(ci, 0)
    n_need_target = target_n if ci == 0 else target_sv
    n_need = max(0, n_need_target - n_have)
    if n_need == 0 or n_have == 0: continue
    mask = y_train == ci
    n_copies = min(CONFIG['aug_max_copies'], max(1, n_need // n_have + (1 if n_need % n_have else 0)))
    X_aug, rr_aug = augment_batch(X_train[mask], X_rr_train[mask], cn, n_copies)
    bal_X.append(X_aug); bal_rr.append(rr_aug); bal_y.append(np.full(len(X_aug), ci, dtype=y_train.dtype))

X_train_bal = np.concatenate(bal_X); X_rr_train_bal = np.concatenate(bal_rr); y_train_bal = np.concatenate(bal_y)
perm = np.random.permutation(len(X_train_bal))
X_train_bal, X_rr_train_bal, y_train_bal = X_train_bal[perm], X_rr_train_bal[perm], y_train_bal[perm]

print(f"Balanced train set: {Counter(y_train_bal)}")
# Out:
# train class distribution: N=119038, S=1528, V=0
# val class distribution: N=15935, S=286, V=0
# test class distribution: N=14948, S=293, V=0
# Balanced train set: Counter({0: 119038, 1: 1528})

# %% [markdown]
# ## 8. CNN Training (Gate + SV Head)
#
# **Constraint 6:** Architecture unchanged. Raw weights ~26KB. Total flash footprint ~71KB.

# %%
# ── Section 8: CNN Training ───────────────────────────────────────────────────
def build_gate_model():
    ecg_in = Input(shape=(WINDOW, 1), name='ecg_input'); x = layers.Reshape((WINDOW, 1, 1))(ecg_in)
    for f,k,d in [(16,7,0.1),(32,5,0.1),(64,5,0.15),(64,3,0.0)]:
        x = layers.Conv2D(f,(k,1),padding='same',use_bias=False,kernel_regularizer=regularizers.l2(CONFIG['l2_reg']))(x)
        x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
        if k >= 5: x = layers.MaxPooling2D((2,1))(x); x = layers.SpatialDropout2D(d)(x)
    x = layers.GlobalAveragePooling2D()(x)
    rr_in = Input(shape=(7,), name='rr_input')
    r = layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(CONFIG['l2_reg']))(rr_in)
    r = layers.Dropout(CONFIG['dropout_rr'])(r); r = layers.Dense(8, activation='relu', kernel_regularizer=regularizers.l2(CONFIG['l2_reg']))(r)
    m = layers.Concatenate()([x, r]); m = layers.Dense(32, use_bias=False)(m)
    m = layers.BatchNormalization()(m); m = layers.Activation('relu')(m); m = layers.Dropout(CONFIG['dropout_merge'])(m)
    out = layers.Dense(1, activation='sigmoid', name='gate_out')(m)
    return Model(inputs=[ecg_in, rr_in], outputs=out)

def build_sv_model():
    ecg_in = Input(shape=(WINDOW, 1), name='ecg_input'); x = layers.Reshape((WINDOW, 1, 1))(ecg_in)
    for f,k,d in [(16,7,0.1),(32,5,0.1),(48,5,0.15),(48,3,0.0)]:
        x = layers.Conv2D(f,(k,1),padding='same',use_bias=False,kernel_regularizer=regularizers.l2(CONFIG['l2_reg']))(x)
        x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
        if k >= 5: x = layers.MaxPooling2D((2,1))(x); x = layers.SpatialDropout2D(d)(x)
    x = layers.GlobalAveragePooling2D()(x)
    rr_in = Input(shape=(7,), name='rr_input')
    r = layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(CONFIG['l2_reg']))(rr_in)
    r = layers.Dropout(CONFIG['dropout_rr'])(r); r = layers.Dense(8, activation='relu', kernel_regularizer=regularizers.l2(CONFIG['l2_reg']))(r)
    m = layers.Concatenate()([x, r]); m = layers.Dense(32, use_bias=False)(m)
    m = layers.BatchNormalization()(m); m = layers.Activation('relu')(m); m = layers.Dropout(CONFIG['dropout_merge'])(m)
    v = layers.Dense(1, activation='sigmoid', name='v_head')(m); s = layers.Dense(1, activation='sigmoid', name='s_head')(m)
    return Model(inputs=[ecg_in, rr_in], outputs=[v, s])

# Gate Training
y_gate_train = (y_train_bal != 0).astype(np.float32)
y_gate_val = (y_class[val_mask] != 0).astype(np.float32)
gate_model = build_gate_model()
gate_model.compile(optimizer=tf.keras.optimizers.Adam(CONFIG['learning_rate']), loss='binary_crossentropy', metrics=[tf.keras.metrics.AUC(name='auc')])

if len(np.unique(y_gate_train.astype(int))) < 2:
    print("⚠ WARNING: Gate training data has only one class! Forcing class weights to 1.0")
    gate_cw = np.array([1.0, 1.0])
else:
    gate_cw = class_weight.compute_class_weight('balanced', classes=np.array([0,1]), y=y_gate_train.astype(int))

print("Training Gate Model...")
gate_history = gate_model.fit([X_train_bal, X_rr_train_bal], y_gate_train,
    validation_data=([X_ecg[val_mask], X_rr_norm[val_mask]], y_gate_val),
    epochs=CONFIG['epochs'], batch_size=CONFIG['batch_size'], class_weight={0: float(gate_cw[0]), 1: float(gate_cw[1])},
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', mode='max', patience=CONFIG['early_stop_patience'], restore_best_weights=True, verbose=1),
               tf.keras.callbacks.ModelCheckpoint(str(ROOT_OUT/'04_models_float'/'gate_float.keras'), monitor='val_auc', mode='max', save_best_only=True, verbose=1)],
    verbose=2)
# Load best checkpoint (callback already saved it)
gate_model = tf.keras.models.load_model(str(ROOT_OUT / '04_models_float' / 'gate_float.keras'), compile=False)

# SV Head Training
print("[2/5] Routing training beats through gate...")
import time as _time
_t0 = _time.time()
gate_probs_train = gate_model.predict([X_train_bal, X_rr_train_bal], batch_size=256, verbose=1).flatten()
print(f"  Gate routing done in {_time.time()-_t0:.1f}s")
routed_mask = gate_probs_train > 0.10
print(f"  Total: {len(routed_mask):,}, Routed: {routed_mask.sum():,}, Rejected: {(~routed_mask).sum():,}")

sv_X = X_train_bal[routed_mask]; sv_rr = X_rr_train_bal[routed_mask]; sv_y = y_train_bal[routed_mask]
y_v = (sv_y == 2).astype(np.float32); y_s = (sv_y == 1).astype(np.float32)

gate_probs_val = gate_model.predict([X_ecg[val_mask], X_rr_norm[val_mask]], batch_size=256, verbose=1).flatten()
routed_val = gate_probs_val > 0.10
sv_X_val = X_ecg[val_mask][routed_val]; sv_rr_val = X_rr_norm[val_mask][routed_val]
y_v_val = (y_class[val_mask][routed_val] == 2).astype(np.float32)
y_s_val = (y_class[val_mask][routed_val] == 1).astype(np.float32)

print(f"SV Train routed: {len(sv_X)} beats. V={int(y_v.sum())}, S={int(y_s.sum())}")
print(f"SV Val routed: {len(sv_X_val)} beats. V={int(y_v_val.sum())}, S={int(y_s_val.sum())}")

# FIX: Safe class weight computation (handles single-class routing gracefully)
def _safe_cw(y_bin, name):
    if len(np.unique(y_bin.astype(int))) < 2:
        print(f'  WARNING: {name} has 1 class. Using weight=1.0')
        return np.array([1.0, 1.0])
    return class_weight.compute_class_weight('balanced', classes=np.array([0,1]), y=y_bin.astype(int))

cw_v = _safe_cw(y_v, "V head train")
cw_s = _safe_cw(y_s, "S head train")
sw_v = np.where(y_v==1, cw_v[1], cw_v[0]).astype(np.float32)
sw_s = np.where(y_s==1, cw_s[1], cw_s[0]).astype(np.float32)

sv_model = build_sv_model()
sv_model.compile(optimizer=tf.keras.optimizers.Adam(CONFIG['learning_rate']),
    loss={'v_head':'binary_crossentropy','s_head':'binary_crossentropy'})

print("\n[3/5] Training SV Head Model...")
sv_history = sv_model.fit([sv_X, sv_rr], {'v_head': y_v, 's_head': y_s},
    sample_weight={'v_head': sw_v, 's_head': sw_s},
    validation_data=([sv_X_val, sv_rr_val], {'v_head': y_v_val, 's_head': y_s_val}),
    epochs=CONFIG['epochs'], batch_size=CONFIG['batch_size'],
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=CONFIG['early_stop_patience'], restore_best_weights=True, verbose=1),
               tf.keras.callbacks.ModelCheckpoint(str(ROOT_OUT/'04_models_float'/'sv_head_float.keras'), monitor='val_loss', mode='min', save_best_only=True, verbose=1)],
    verbose=2)
# Load best checkpoint
sv_model = tf.keras.models.load_model(str(ROOT_OUT / '04_models_float' / 'sv_head_float.keras'), compile=False)
print("[3/5] SV/V training complete")
print("CNN Training Complete.")
# Out:
# Training Gate Model...
# Epoch 1/60
#
# Epoch 1: val_auc improved from -inf to 0.99921, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 8s - loss: 0.2299 - auc: 0.9800 - val_loss: 0.0848 - val_auc: 0.9992 - 8s/epoch - 17ms/step
# Epoch 2/60
#
# Epoch 2: val_auc improved from 0.99921 to 0.99935, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 6s - loss: 0.0796 - auc: 0.9969 - val_loss: 0.0685 - val_auc: 0.9993 - 6s/epoch - 13ms/step
# Epoch 3/60
#
# Epoch 3: val_auc improved from 0.99935 to 0.99955, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 5s - loss: 0.0520 - auc: 0.9987 - val_loss: 0.0382 - val_auc: 0.9996 - 5s/epoch - 12ms/step
# Epoch 4/60
#
# Epoch 4: val_auc improved from 0.99955 to 0.99996, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 5s - loss: 0.0412 - auc: 0.9991 - val_loss: 0.0324 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 5/60
#
# Epoch 5: val_auc did not improve from 0.99996
# 471/471 - 5s - loss: 0.0416 - auc: 0.9990 - val_loss: 0.0335 - val_auc: 0.9999 - 5s/epoch - 11ms/step
# Epoch 6/60
#
# Epoch 6: val_auc did not improve from 0.99996
# 471/471 - 5s - loss: 0.0359 - auc: 0.9993 - val_loss: 0.0347 - val_auc: 0.9999 - 5s/epoch - 12ms/step
# Epoch 7/60
#
# Epoch 7: val_auc improved from 0.99996 to 0.99997, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 5s - loss: 0.0324 - auc: 0.9994 - val_loss: 0.0274 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 8/60
#
# Epoch 8: val_auc did not improve from 0.99997
# 471/471 - 6s - loss: 0.0299 - auc: 0.9994 - val_loss: 0.0227 - val_auc: 0.9999 - 6s/epoch - 12ms/step
# Epoch 9/60
#
# Epoch 9: val_auc improved from 0.99997 to 0.99998, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 7s - loss: 0.0274 - auc: 0.9994 - val_loss: 0.0207 - val_auc: 1.0000 - 7s/epoch - 14ms/step
# Epoch 10/60
#
# Epoch 10: val_auc did not improve from 0.99998
# 471/471 - 6s - loss: 0.0313 - auc: 0.9988 - val_loss: 0.0248 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 11/60
#
# Epoch 11: val_auc did not improve from 0.99998
# 471/471 - 5s - loss: 0.0269 - auc: 0.9991 - val_loss: 0.0171 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 12/60
#
# Epoch 12: val_auc did not improve from 0.99998
# 471/471 - 5s - loss: 0.0208 - auc: 0.9996 - val_loss: 0.0201 - val_auc: 0.9999 - 5s/epoch - 11ms/step
# Epoch 13/60
#
# Epoch 13: val_auc improved from 0.99998 to 0.99999, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 6s - loss: 0.0210 - auc: 0.9996 - val_loss: 0.0138 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 14/60
#
# Epoch 14: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0198 - auc: 0.9997 - val_loss: 0.0126 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 15/60
#
# Epoch 15: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0182 - auc: 0.9996 - val_loss: 0.0125 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 16/60
#
# Epoch 16: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0170 - auc: 0.9996 - val_loss: 0.0137 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 17/60
#
# Epoch 17: val_auc improved from 0.99999 to 0.99999, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 6s - loss: 0.0162 - auc: 0.9996 - val_loss: 0.0128 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 18/60
#
# Epoch 18: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0140 - auc: 0.9997 - val_loss: 0.0133 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 19/60
#
# Epoch 19: val_auc improved from 0.99999 to 0.99999, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 6s - loss: 0.0138 - auc: 0.9997 - val_loss: 0.0097 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 20/60
#
# Epoch 20: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0175 - auc: 0.9996 - val_loss: 0.0125 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 21/60
#
# Epoch 21: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0160 - auc: 0.9996 - val_loss: 0.0120 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 22/60
#
# Epoch 22: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0140 - auc: 0.9997 - val_loss: 0.0105 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 23/60
#
# Epoch 23: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0142 - auc: 0.9997 - val_loss: 0.0112 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 24/60
#
# Epoch 24: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0119 - auc: 0.9998 - val_loss: 0.0083 - val_auc: 1.0000 - 6s/epoch - 13ms/step
# Epoch 25/60
#
# Epoch 25: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0137 - auc: 0.9997 - val_loss: 0.0153 - val_auc: 0.9997 - 6s/epoch - 12ms/step
# Epoch 26/60
#
# Epoch 26: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0140 - auc: 0.9997 - val_loss: 0.0097 - val_auc: 0.9999 - 6s/epoch - 12ms/step
# Epoch 27/60
#
# Epoch 27: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0155 - auc: 0.9994 - val_loss: 0.0107 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 28/60
#
# Epoch 28: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0152 - auc: 0.9997 - val_loss: 0.0125 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 29/60
#
# Epoch 29: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0141 - auc: 0.9998 - val_loss: 0.0140 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 30/60
#
# Epoch 30: val_auc improved from 0.99999 to 0.99999, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 5s - loss: 0.0124 - auc: 0.9998 - val_loss: 0.0103 - val_auc: 1.0000 - 5s/epoch - 12ms/step
# Epoch 31/60
#
# Epoch 31: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0152 - auc: 0.9997 - val_loss: 0.0112 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 32/60
#
# Epoch 32: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0124 - auc: 0.9997 - val_loss: 0.0103 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 33/60
#
# Epoch 33: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0136 - auc: 0.9997 - val_loss: 0.0126 - val_auc: 0.9998 - 5s/epoch - 11ms/step
# Epoch 34/60
#
# Epoch 34: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0127 - auc: 0.9998 - val_loss: 0.0094 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 35/60
#
# Epoch 35: val_auc improved from 0.99999 to 0.99999, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 6s - loss: 0.0102 - auc: 0.9998 - val_loss: 0.0086 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 36/60
#
# Epoch 36: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0111 - auc: 0.9998 - val_loss: 0.0086 - val_auc: 1.0000 - 6s/epoch - 13ms/step
# Epoch 37/60
#
# Epoch 37: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0120 - auc: 0.9997 - val_loss: 0.0108 - val_auc: 0.9999 - 5s/epoch - 12ms/step
# Epoch 38/60
#
# Epoch 38: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0098 - auc: 0.9998 - val_loss: 0.0072 - val_auc: 1.0000 - 5s/epoch - 12ms/step
# Epoch 39/60
#
# Epoch 39: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0111 - auc: 0.9998 - val_loss: 0.0097 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 40/60
#
# Epoch 40: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0107 - auc: 0.9998 - val_loss: 0.0086 - val_auc: 1.0000 - 6s/epoch - 13ms/step
# Epoch 41/60
#
# Epoch 41: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0107 - auc: 0.9998 - val_loss: 0.0109 - val_auc: 1.0000 - 5s/epoch - 12ms/step
# Epoch 42/60
#
# Epoch 42: val_auc improved from 0.99999 to 0.99999, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\gate_float.keras
# 471/471 - 6s - loss: 0.0093 - auc: 0.9998 - val_loss: 0.0062 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 43/60
#
# Epoch 43: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0112 - auc: 0.9998 - val_loss: 0.0110 - val_auc: 0.9999 - 5s/epoch - 11ms/step
# Epoch 44/60
#
# Epoch 44: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0124 - auc: 0.9997 - val_loss: 0.0101 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 45/60
#
# Epoch 45: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0102 - auc: 0.9998 - val_loss: 0.0088 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 46/60
#
# Epoch 46: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0104 - auc: 0.9998 - val_loss: 0.0082 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 47/60
#
# Epoch 47: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0091 - auc: 0.9998 - val_loss: 0.0067 - val_auc: 1.0000 - 5s/epoch - 12ms/step
# Epoch 48/60
#
# Epoch 48: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0182 - auc: 0.9991 - val_loss: 0.0086 - val_auc: 0.9981 - 5s/epoch - 12ms/step
# Epoch 49/60
#
# Epoch 49: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0109 - auc: 0.9998 - val_loss: 0.0143 - val_auc: 0.9997 - 5s/epoch - 12ms/step
# Epoch 50/60
#
# Epoch 50: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0112 - auc: 0.9997 - val_loss: 0.0102 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 51/60
#
# Epoch 51: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0103 - auc: 0.9999 - val_loss: 0.0083 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 52/60
#
# Epoch 52: val_auc did not improve from 0.99999
# 471/471 - 6s - loss: 0.0094 - auc: 0.9999 - val_loss: 0.0072 - val_auc: 1.0000 - 6s/epoch - 12ms/step
# Epoch 53/60
#
# Epoch 53: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0110 - auc: 0.9998 - val_loss: 0.0083 - val_auc: 1.0000 - 5s/epoch - 12ms/step
# Epoch 54/60
# Restoring model weights from the end of the best epoch: 42.
#
# Epoch 54: val_auc did not improve from 0.99999
# 471/471 - 5s - loss: 0.0100 - auc: 0.9998 - val_loss: 0.0104 - val_auc: 1.0000 - 5s/epoch - 11ms/step
# Epoch 54: early stopping
# [2/5] Routing training beats through gate...
# 471/471 [==============================] - 1s 3ms/step
#   Gate routing done in 1.6s
#   Total: 120,566, Routed: 1,824, Rejected: 118,742
# 64/64 [==============================] - 0s 3ms/step
# SV Train routed: 1824 beats. V=0, S=1528
# SV Val routed: 323 beats. V=0, S=286
#   WARNING: V head train has 1 class. Using weight=1.0
#
# [3/5] Training SV Head Model...
# Epoch 1/60
#
# Epoch 1: val_loss improved from inf to 1.56489, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 3s - loss: 1.5311 - v_head_loss: 0.7700 - s_head_loss: 0.7479 - val_loss: 1.5649 - val_v_head_loss: 0.8155 - val_s_head_loss: 0.7362 - 3s/epoch - 315ms/step
# Epoch 2/60
#
# Epoch 2: val_loss improved from 1.56489 to 1.47239, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 1.4194 - v_head_loss: 0.6678 - s_head_loss: 0.7383 - val_loss: 1.4724 - val_v_head_loss: 0.7337 - val_s_head_loss: 0.7255 - 243ms/epoch - 30ms/step
# Epoch 3/60
#
# Epoch 3: val_loss improved from 1.47239 to 1.36857, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 1.2852 - v_head_loss: 0.5804 - s_head_loss: 0.6915 - val_loss: 1.3686 - val_v_head_loss: 0.6510 - val_s_head_loss: 0.7043 - 278ms/epoch - 35ms/step
# Epoch 4/60
#
# Epoch 4: val_loss improved from 1.36857 to 1.29706, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 1.2136 - v_head_loss: 0.5194 - s_head_loss: 0.6809 - val_loss: 1.2971 - val_v_head_loss: 0.5975 - val_s_head_loss: 0.6863 - 263ms/epoch - 33ms/step
# Epoch 5/60
#
# Epoch 5: val_loss improved from 1.29706 to 1.21334, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 1.1518 - v_head_loss: 0.4771 - s_head_loss: 0.6614 - val_loss: 1.2133 - val_v_head_loss: 0.5369 - val_s_head_loss: 0.6631 - 284ms/epoch - 36ms/step
# Epoch 6/60
#
# Epoch 6: val_loss improved from 1.21334 to 1.12404, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 1.0696 - v_head_loss: 0.4070 - s_head_loss: 0.6494 - val_loss: 1.1240 - val_v_head_loss: 0.4788 - val_s_head_loss: 0.6319 - 264ms/epoch - 33ms/step
# Epoch 7/60
#
# Epoch 7: val_loss improved from 1.12404 to 1.02898, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 1.0070 - v_head_loss: 0.3707 - s_head_loss: 0.6231 - val_loss: 1.0290 - val_v_head_loss: 0.4181 - val_s_head_loss: 0.5976 - 267ms/epoch - 33ms/step
# Epoch 8/60
#
# Epoch 8: val_loss improved from 1.02898 to 0.94616, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.9744 - v_head_loss: 0.3515 - s_head_loss: 0.6096 - val_loss: 0.9462 - val_v_head_loss: 0.3651 - val_s_head_loss: 0.5678 - 280ms/epoch - 35ms/step
# Epoch 9/60
#
# Epoch 9: val_loss improved from 0.94616 to 0.87816, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.9165 - v_head_loss: 0.3141 - s_head_loss: 0.5891 - val_loss: 0.8782 - val_v_head_loss: 0.3224 - val_s_head_loss: 0.5424 - 296ms/epoch - 37ms/step
# Epoch 10/60
#
# Epoch 10: val_loss improved from 0.87816 to 0.81374, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.9060 - v_head_loss: 0.2869 - s_head_loss: 0.6058 - val_loss: 0.8137 - val_v_head_loss: 0.2841 - val_s_head_loss: 0.5164 - 266ms/epoch - 33ms/step
# Epoch 11/60
#
# Epoch 11: val_loss improved from 0.81374 to 0.75859, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.8426 - v_head_loss: 0.2599 - s_head_loss: 0.5695 - val_loss: 0.7586 - val_v_head_loss: 0.2515 - val_s_head_loss: 0.4938 - 257ms/epoch - 32ms/step
# Epoch 12/60
#
# Epoch 12: val_loss improved from 0.75859 to 0.70104, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.8025 - v_head_loss: 0.2371 - s_head_loss: 0.5521 - val_loss: 0.7010 - val_v_head_loss: 0.2246 - val_s_head_loss: 0.4632 - 267ms/epoch - 33ms/step
# Epoch 13/60
#
# Epoch 13: val_loss improved from 0.70104 to 0.64336, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.7900 - v_head_loss: 0.2241 - s_head_loss: 0.5526 - val_loss: 0.6434 - val_v_head_loss: 0.2015 - val_s_head_loss: 0.4286 - 278ms/epoch - 35ms/step
# Epoch 14/60
#
# Epoch 14: val_loss improved from 0.64336 to 0.58850, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.7651 - v_head_loss: 0.2079 - s_head_loss: 0.5439 - val_loss: 0.5885 - val_v_head_loss: 0.1791 - val_s_head_loss: 0.3961 - 268ms/epoch - 33ms/step
# Epoch 15/60
#
# Epoch 15: val_loss improved from 0.58850 to 0.53924, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.6992 - v_head_loss: 0.1882 - s_head_loss: 0.4978 - val_loss: 0.5392 - val_v_head_loss: 0.1603 - val_s_head_loss: 0.3656 - 256ms/epoch - 32ms/step
# Epoch 16/60
#
# Epoch 16: val_loss improved from 0.53924 to 0.49995, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.7051 - v_head_loss: 0.1816 - s_head_loss: 0.5102 - val_loss: 0.5000 - val_v_head_loss: 0.1440 - val_s_head_loss: 0.3427 - 279ms/epoch - 35ms/step
# Epoch 17/60
#
# Epoch 17: val_loss improved from 0.49995 to 0.46622, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.6730 - v_head_loss: 0.1690 - s_head_loss: 0.4907 - val_loss: 0.4662 - val_v_head_loss: 0.1332 - val_s_head_loss: 0.3198 - 436ms/epoch - 54ms/step
# Epoch 18/60
#
# Epoch 18: val_loss improved from 0.46622 to 0.43597, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.6548 - v_head_loss: 0.1567 - s_head_loss: 0.4849 - val_loss: 0.4360 - val_v_head_loss: 0.1208 - val_s_head_loss: 0.3019 - 267ms/epoch - 33ms/step
# Epoch 19/60
#
# Epoch 19: val_loss improved from 0.43597 to 0.41157, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.6505 - v_head_loss: 0.1601 - s_head_loss: 0.4772 - val_loss: 0.4116 - val_v_head_loss: 0.1101 - val_s_head_loss: 0.2883 - 293ms/epoch - 37ms/step
# Epoch 20/60
#
# Epoch 20: val_loss improved from 0.41157 to 0.38771, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.6207 - v_head_loss: 0.1388 - s_head_loss: 0.4687 - val_loss: 0.3877 - val_v_head_loss: 0.0990 - val_s_head_loss: 0.2755 - 312ms/epoch - 39ms/step
# Epoch 21/60
#
# Epoch 21: val_loss improved from 0.38771 to 0.36754, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.6130 - v_head_loss: 0.1360 - s_head_loss: 0.4638 - val_loss: 0.3675 - val_v_head_loss: 0.0905 - val_s_head_loss: 0.2638 - 291ms/epoch - 36ms/step
# Epoch 22/60
#
# Epoch 22: val_loss improved from 0.36754 to 0.35023, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.5698 - v_head_loss: 0.1216 - s_head_loss: 0.4349 - val_loss: 0.3502 - val_v_head_loss: 0.0832 - val_s_head_loss: 0.2538 - 312ms/epoch - 39ms/step
# Epoch 23/60
#
# Epoch 23: val_loss improved from 0.35023 to 0.33591, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.5748 - v_head_loss: 0.1176 - s_head_loss: 0.4440 - val_loss: 0.3359 - val_v_head_loss: 0.0773 - val_s_head_loss: 0.2453 - 342ms/epoch - 43ms/step
# Epoch 24/60
#
# Epoch 24: val_loss improved from 0.33591 to 0.32634, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.5509 - v_head_loss: 0.1149 - s_head_loss: 0.4228 - val_loss: 0.3263 - val_v_head_loss: 0.0740 - val_s_head_loss: 0.2391 - 301ms/epoch - 38ms/step
# Epoch 25/60
#
# Epoch 25: val_loss improved from 0.32634 to 0.31872, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.5342 - v_head_loss: 0.1064 - s_head_loss: 0.4146 - val_loss: 0.3187 - val_v_head_loss: 0.0720 - val_s_head_loss: 0.2335 - 296ms/epoch - 37ms/step
# Epoch 26/60
#
# Epoch 26: val_loss improved from 0.31872 to 0.30782, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.5445 - v_head_loss: 0.1001 - s_head_loss: 0.4312 - val_loss: 0.3078 - val_v_head_loss: 0.0681 - val_s_head_loss: 0.2265 - 318ms/epoch - 40ms/step
# Epoch 27/60
#
# Epoch 27: val_loss improved from 0.30782 to 0.29869, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.5343 - v_head_loss: 0.0974 - s_head_loss: 0.4237 - val_loss: 0.2987 - val_v_head_loss: 0.0644 - val_s_head_loss: 0.2211 - 300ms/epoch - 38ms/step
# Epoch 28/60
#
# Epoch 28: val_loss did not improve from 0.29869
# 8/8 - 0s - loss: 0.4929 - v_head_loss: 0.0926 - s_head_loss: 0.3872 - val_loss: 0.2990 - val_v_head_loss: 0.0647 - val_s_head_loss: 0.2211 - 155ms/epoch - 19ms/step
# Epoch 29/60
#
# Epoch 29: val_loss did not improve from 0.29869
# 8/8 - 0s - loss: 0.4944 - v_head_loss: 0.0898 - s_head_loss: 0.3914 - val_loss: 0.3038 - val_v_head_loss: 0.0655 - val_s_head_loss: 0.2251 - 153ms/epoch - 19ms/step
# Epoch 30/60
#
# Epoch 30: val_loss did not improve from 0.29869
# 8/8 - 0s - loss: 0.4878 - v_head_loss: 0.0857 - s_head_loss: 0.3889 - val_loss: 0.3105 - val_v_head_loss: 0.0662 - val_s_head_loss: 0.2312 - 139ms/epoch - 17ms/step
# Epoch 31/60
#
# Epoch 31: val_loss did not improve from 0.29869
# 8/8 - 0s - loss: 0.4746 - v_head_loss: 0.0773 - s_head_loss: 0.3841 - val_loss: 0.3108 - val_v_head_loss: 0.0653 - val_s_head_loss: 0.2323 - 140ms/epoch - 17ms/step
# Epoch 32/60
#
# Epoch 32: val_loss did not improve from 0.29869
# 8/8 - 0s - loss: 0.4590 - v_head_loss: 0.0750 - s_head_loss: 0.3708 - val_loss: 0.3054 - val_v_head_loss: 0.0625 - val_s_head_loss: 0.2297 - 134ms/epoch - 17ms/step
# Epoch 33/60
#
# Epoch 33: val_loss improved from 0.29869 to 0.28096, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.4575 - v_head_loss: 0.0736 - s_head_loss: 0.3708 - val_loss: 0.2810 - val_v_head_loss: 0.0508 - val_s_head_loss: 0.2170 - 274ms/epoch - 34ms/step
# Epoch 34/60
#
# Epoch 34: val_loss improved from 0.28096 to 0.26789, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.4390 - v_head_loss: 0.0705 - s_head_loss: 0.3553 - val_loss: 0.2679 - val_v_head_loss: 0.0455 - val_s_head_loss: 0.2092 - 292ms/epoch - 36ms/step
# Epoch 35/60
#
# Epoch 35: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.4475 - v_head_loss: 0.0650 - s_head_loss: 0.3694 - val_loss: 0.2709 - val_v_head_loss: 0.0473 - val_s_head_loss: 0.2104 - 144ms/epoch - 18ms/step
# Epoch 36/60
#
# Epoch 36: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.4314 - v_head_loss: 0.0628 - s_head_loss: 0.3554 - val_loss: 0.2839 - val_v_head_loss: 0.0489 - val_s_head_loss: 0.2218 - 130ms/epoch - 16ms/step
# Epoch 37/60
#
# Epoch 37: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.4172 - v_head_loss: 0.0607 - s_head_loss: 0.3434 - val_loss: 0.3018 - val_v_head_loss: 0.0508 - val_s_head_loss: 0.2379 - 178ms/epoch - 22ms/step
# Epoch 38/60
#
# Epoch 38: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.4156 - v_head_loss: 0.0589 - s_head_loss: 0.3435 - val_loss: 0.3140 - val_v_head_loss: 0.0531 - val_s_head_loss: 0.2477 - 141ms/epoch - 18ms/step
# Epoch 39/60
#
# Epoch 39: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.4102 - v_head_loss: 0.0590 - s_head_loss: 0.3381 - val_loss: 0.3266 - val_v_head_loss: 0.0553 - val_s_head_loss: 0.2582 - 145ms/epoch - 18ms/step
# Epoch 40/60
#
# Epoch 40: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.4161 - v_head_loss: 0.0544 - s_head_loss: 0.3486 - val_loss: 0.3261 - val_v_head_loss: 0.0545 - val_s_head_loss: 0.2585 - 125ms/epoch - 16ms/step
# Epoch 41/60
#
# Epoch 41: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.3938 - v_head_loss: 0.0520 - s_head_loss: 0.3287 - val_loss: 0.3041 - val_v_head_loss: 0.0483 - val_s_head_loss: 0.2428 - 161ms/epoch - 20ms/step
# Epoch 42/60
#
# Epoch 42: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.3917 - v_head_loss: 0.0532 - s_head_loss: 0.3254 - val_loss: 0.2918 - val_v_head_loss: 0.0431 - val_s_head_loss: 0.2356 - 170ms/epoch - 21ms/step
# Epoch 43/60
#
# Epoch 43: val_loss did not improve from 0.26789
# 8/8 - 0s - loss: 0.4048 - v_head_loss: 0.0486 - s_head_loss: 0.3431 - val_loss: 0.2720 - val_v_head_loss: 0.0380 - val_s_head_loss: 0.2210 - 164ms/epoch - 21ms/step
# Epoch 44/60
#
# Epoch 44: val_loss improved from 0.26789 to 0.26755, saving model to artifacts\v11_leadi_runs\20260713_233009_eeb329c1\04_models_float\sv_head_float.keras
# 8/8 - 0s - loss: 0.3756 - v_head_loss: 0.0483 - s_head_loss: 0.3142 - val_loss: 0.2676 - val_v_head_loss: 0.0345 - val_s_head_loss: 0.2200 - 314ms/epoch - 39ms/step
# Epoch 45/60
#
# Epoch 45: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3703 - v_head_loss: 0.0496 - s_head_loss: 0.3076 - val_loss: 0.2700 - val_v_head_loss: 0.0330 - val_s_head_loss: 0.2239 - 177ms/epoch - 22ms/step
# Epoch 46/60
#
# Epoch 46: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3752 - v_head_loss: 0.0450 - s_head_loss: 0.3172 - val_loss: 0.2730 - val_v_head_loss: 0.0320 - val_s_head_loss: 0.2280 - 171ms/epoch - 21ms/step
# Epoch 47/60
#
# Epoch 47: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3799 - v_head_loss: 0.0459 - s_head_loss: 0.3209 - val_loss: 0.2726 - val_v_head_loss: 0.0303 - val_s_head_loss: 0.2292 - 165ms/epoch - 21ms/step
# Epoch 48/60
#
# Epoch 48: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3608 - v_head_loss: 0.0393 - s_head_loss: 0.3084 - val_loss: 0.2859 - val_v_head_loss: 0.0308 - val_s_head_loss: 0.2420 - 156ms/epoch - 20ms/step
# Epoch 49/60
#
# Epoch 49: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3568 - v_head_loss: 0.0396 - s_head_loss: 0.3042 - val_loss: 0.2887 - val_v_head_loss: 0.0285 - val_s_head_loss: 0.2472 - 156ms/epoch - 20ms/step
# Epoch 50/60
#
# Epoch 50: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3606 - v_head_loss: 0.0384 - s_head_loss: 0.3092 - val_loss: 0.2959 - val_v_head_loss: 0.0256 - val_s_head_loss: 0.2572 - 153ms/epoch - 19ms/step
# Epoch 51/60
#
# Epoch 51: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3722 - v_head_loss: 0.0383 - s_head_loss: 0.3209 - val_loss: 0.2979 - val_v_head_loss: 0.0232 - val_s_head_loss: 0.2616 - 159ms/epoch - 20ms/step
# Epoch 52/60
#
# Epoch 52: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3402 - v_head_loss: 0.0384 - s_head_loss: 0.2889 - val_loss: 0.3236 - val_v_head_loss: 0.0249 - val_s_head_loss: 0.2856 - 156ms/epoch - 19ms/step
# Epoch 53/60
#
# Epoch 53: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3573 - v_head_loss: 0.0356 - s_head_loss: 0.3087 - val_loss: 0.3344 - val_v_head_loss: 0.0255 - val_s_head_loss: 0.2959 - 158ms/epoch - 20ms/step
# Epoch 54/60
#
# Epoch 54: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3311 - v_head_loss: 0.0354 - s_head_loss: 0.2827 - val_loss: 0.3368 - val_v_head_loss: 0.0251 - val_s_head_loss: 0.2987 - 160ms/epoch - 20ms/step
# Epoch 55/60
#
# Epoch 55: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3460 - v_head_loss: 0.0349 - s_head_loss: 0.2981 - val_loss: 0.3353 - val_v_head_loss: 0.0236 - val_s_head_loss: 0.2988 - 150ms/epoch - 19ms/step
# Epoch 56/60
# Restoring model weights from the end of the best epoch: 44.
#
# Epoch 56: val_loss did not improve from 0.26755
# 8/8 - 0s - loss: 0.3335 - v_head_loss: 0.0312 - s_head_loss: 0.2893 - val_loss: 0.3584 - val_v_head_loss: 0.0241 - val_s_head_loss: 0.3214 - 163ms/epoch - 20ms/step
# Epoch 56: early stopping
# [3/5] SV/V training complete
# CNN Training Complete.

# %% [markdown]
# ## 9. 3-Number Evaluation
#
# **Constraint 7:**
# 1. Primary: Held-out Lead I test split (PTB-XL/CPSC).
# 2. Generalization: INCART (Lead I).
# 3. Legacy: MIT-BIH (Lead II).

# %%
# ── Section 9: 3-Number Evaluation ───────────────────────────────────────────
# 1. Primary Test Split (PTB-XL/CPSC held-out)
y_test = y_class[test_mask]
gate_p_test = gate_model.predict([X_ecg[test_mask], X_rr_norm[test_mask]], batch_size=256, verbose=0).flatten()
v_p_test, s_p_test = sv_model.predict([X_ecg[test_mask], X_rr_norm[test_mask]], batch_size=256, verbose=0)
v_p_test = v_p_test.flatten(); s_p_test = s_p_test.flatten()

# Threshold sweep on VAL ONLY. Gate pinned to 0.10.
y_val = y_class[val_mask]
gate_p_val = gate_model.predict([X_ecg[val_mask], X_rr_norm[val_mask]], batch_size=256, verbose=0).flatten()
v_p_val, s_p_val = sv_model.predict([X_ecg[val_mask], X_rr_norm[val_mask]], batch_size=256, verbose=0)
v_p_val = v_p_val.flatten(); s_p_val = s_p_val.flatten()

# FIX: Margin-based decoder (not V-first). V and S compete fairly.
def decode_cascade(gate_probs, v_probs, s_probs, thr):
    predictions = np.zeros(len(gate_probs), dtype=np.int32)
    routed = gate_probs > thr['gate']
    v_margin = v_probs - thr['v']
    s_margin = s_probs - thr['s']
    choose_v = routed & (v_margin > 0) & (v_margin >= s_margin)
    choose_s = routed & (s_margin > 0) & (s_margin > v_margin)
    predictions[choose_v] = 2
    predictions[choose_s] = 1
    return predictions

best_f1 = 0; best_thr = {'gate': 0.10, 'v': 0.20, 's': 0.50}
GATE_THR_FIXED = 0.10

# Coarse grid
for v_t in np.arange(0.10, 0.50, 0.05):
    for s_t in np.arange(0.10, 0.80, 0.05):
        thr_dict = {'gate': GATE_THR_FIXED, 'v': float(v_t), 's': float(s_t)}
        y_pred_val = decode_cascade(gate_p_val, v_p_val, s_p_val, thr_dict)
        f1 = f1_score(y_val, y_pred_val, average='macro', zero_division=0)
        if f1 > best_f1:
            best_f1 = f1; best_thr = {'gate': GATE_THR_FIXED, 'v': float(v_t), 's': float(s_t)}

# Apply val-chosen thresholds to TEST set
y_pred_primary = decode_cascade(gate_p_test, v_p_test, s_p_test, best_thr)
print(f"Thresholds (chosen on val): {best_thr}")
print(f"Test set class distribution: {Counter(y_test)}")
print(f"Predicted class distribution: {Counter(y_pred_primary)}")

cm_primary = confusion_matrix(y_test, y_pred_primary, labels=[0,1,2])
report_primary = classification_report(y_test, y_pred_primary, labels=[0,1,2],
                                       target_names=['N','S','V'], output_dict=True, zero_division=0)
print(f"Number 1 (Primary - Lead I Test): Macro F1 = {report_primary['macro avg']['f1-score']:.4f}")
print(f"  V Recall = {report_primary['V']['recall']:.4f}, S F1 = {report_primary['S']['f1-score']:.4f}")
with open(ROOT_OUT / '06_metrics' / 'primary_test_metrics.json', 'w', encoding='utf-8') as f:
    jdumps({'report': report_primary, 'thresholds': best_thr, 'cm': cm_primary.tolist()}, f, indent=2)

# 2 & 3: INCART and MIT-BIH (Cross-database) — BATCHED
def evaluate_external(dataset_name, path, channel_idx=0):
    hea_files = sorted(glob.glob(os.path.join(path, '*.hea')))
    all_y_true, all_y_pred = [], []
    BEAT_MAP = {'N':'N','L':'N','R':'N','e':'N','j':'N','A':'S','a':'S','J':'S','S':'S','V':'V','E':'V'}
    
    for hf in hea_files:
        rec_id = os.path.splitext(os.path.basename(hf))[0]
        try:
            rec = wfdb.rdrecord(os.path.join(path, rec_id))
            ann = wfdb.rdann(os.path.join(path, rec_id), 'atr')
            sig = preprocess_signal(rec.p_signal[:, channel_idx], rec.fs)
            peaks_sec = ann.sample / rec.fs
            peaks = np.round(ann.sample * 250.0 / rec.fs).astype(int)
            
            # FIX: Batch per record
            record_ecg, record_rr, record_labels = [], [], []
            for i, peak in enumerate(peaks):
                if peak - HALF < 0 or peak + HALF >= len(sig): continue
                rr_feat = compute_rr_features(peaks_sec, i)
                if rr_feat is None: continue
                aami = BEAT_MAP.get(ann.symbol[i], 'IGNORE')
                if aami == 'IGNORE': continue
                record_ecg.append(sig[peak-HALF:peak+HALF].reshape(-1, 1))
                record_rr.append(rr_feat)
                record_labels.append({'N':0,'S':1,'V':2}[aami])
            
            if not record_ecg: continue
            record_ecg = np.asarray(record_ecg, dtype=np.float32)
            record_rr = rr_scaler.transform(np.asarray(record_rr, dtype=np.float32)).astype(np.float32)
            
            # Batch predict
            g_p = gate_model.predict([record_ecg, record_rr], batch_size=512, verbose=0).flatten()
            v_p, s_p = sv_model.predict([record_ecg, record_rr], batch_size=512, verbose=0)
            v_p = v_p.flatten(); s_p = s_p.flatten()
            
            # Decode
            preds = decode_cascade(g_p, v_p, s_p, best_thr)
            all_y_true.extend(record_labels)
            all_y_pred.extend(preds.tolist())
        except: pass
        
    if not all_y_true: return None
    y_t = np.array(all_y_true); y_p = np.array(all_y_pred)
    report = classification_report(y_t, y_p, labels=[0,1,2],
                                   target_names=['N','S','V'], output_dict=True, zero_division=0)
    print(f"Number {'2' if dataset_name=='INCART' else '3'} ({dataset_name}): Macro F1 = {report['macro avg']['f1-score']:.4f}, V Rec = {report['V']['recall']:.4f}")
    return report

incart_report = evaluate_external('INCART', DATASET_PATHS['incart'], 0)
if incart_report:
    with open(ROOT_OUT / '06_metrics' / 'incart_metrics.json', 'w', encoding='utf-8') as f: jdumps(incart_report, f, indent=2)

mitdb_report = evaluate_external('MIT-BIH', DATASET_PATHS['mitdb'], 0)
if mitdb_report:
    with open(ROOT_OUT / '06_metrics' / 'mitdb_metrics.json', 'w', encoding='utf-8') as f: jdumps(mitdb_report, f, indent=2)
# Out:
# Thresholds (chosen on val): {'gate': 0.1, 'v': 0.1, 's': 0.3500000000000001}
# Test set class distribution: Counter({0: 14948, 1: 293})
# Predicted class distribution: Counter({0: 14937, 1: 304})
# Number 1 (Primary - Lead I Test): Macro F1 = 0.6593
#   V Recall = 0.0000, S F1 = 0.9782
# Number 2 (INCART): Macro F1 = 0.3831, V Rec = 0.0000
# Number 3 (MIT-BIH): Macro F1 = 0.3981, V Rec = 0.0000

# %% [markdown]
# ## 10. Clinical Event Engine Validation
#
# **Constraint 8:** Validate AFib on PhysioNet 2017 + LTAFDB. Validate VT on CUDB. Validate NLMS on NSTDB.

# %%
# ── Section 10: Clinical Event Engine Validation ─────────────────────────────
def clinical_event_engine(rr_intervals_ms, beat_classes, min_beats=30):
    n = len(rr_intervals_ms)
    if n < min_beats: return {'afib': False, 'vt': False}
    rr = np.array(rr_intervals_ms, dtype=np.float64)
    mean_rr = np.mean(rr); sdnn = np.std(rr); cov = sdnn / max(mean_rr, 1)
    diff = np.diff(rr); rmssd = np.sqrt(np.mean(diff**2)); prr50 = np.mean(np.abs(diff) > 50)
    hr = 60000 / max(mean_rr, 1)
    
    bc = np.array(beat_classes); consec_v = 0; max_v_run = 0
    for i in range(n):
        if bc[i] == 2: consec_v += 1; max_v_run = max(max_v_run, consec_v)
        else: consec_v = 0
    
    vt = (max_v_run >= 5) and (hr > 100)
    afib = (cov > 0.12) and (prr50 > 0.10) and (rmssd > 30) and (400 < mean_rr < 1200) and not (max_v_run >= 3)
    return {'afib': bool(afib), 'vt': bool(vt)}

# 1. PhysioNet 2017 (AFib on true single-lead wearable)
p2017_ref = os.path.join(DATASET_PATHS['p2017'], 'REFERENCES.csv')
if os.path.isfile(p2017_ref):
    df_2017 = pd.read_csv(p2017_ref, header=None, names=['record', 'label'])
    afib_correct = 0; afib_total = 0; normal_correct = 0; normal_total = 0
    
    for idx, row in df_2017.iterrows():
        rec_id = row['record']; label = row['label']
        if label not in ['N', 'A']: continue # Skip O and ~
        
        # Challenge2017 has nested structure: training/A0X/A0XXXX.hea
        # Use glob to find the record recursively
        hea_pattern = os.path.join(DATASET_PATHS['p2017'], '**', rec_id + '.hea')
        hea_matches = glob.glob(hea_pattern, recursive=True)
        if not hea_matches:
            continue
        path = os.path.splitext(hea_matches[0])[0]
        if not os.path.isfile(path + '.hea'): continue
        try:
            rec = wfdb.rdrecord(path)
            sig = preprocess_signal(rec.p_signal[:, 0], rec.fs)
            peaks = detect_rpeaks(sig)
            if len(peaks) < 30: continue
            rr_ms = np.diff(peaks) / 250.0 * 1000
            bc = [0] * len(rr_ms) # Placeholder beats
            res = clinical_event_engine(rr_ms, bc)
            
            if label == 'A': # AFib record
                afib_total += 1
                if res['afib']: afib_correct += 1
            elif label == 'N': # Normal record
                normal_total += 1
                if not res['afib']: normal_correct += 1
        except: pass
        
    p2017_sens = afib_correct / max(afib_total, 1)
    p2017_spec = normal_correct / max(normal_total, 1)
    print(f"PhysioNet 2017 AFib: Sensitivity={p2017_sens:.4f}, Specificity={p2017_spec:.4f}")
    with open(ROOT_OUT / '08_engine_eval' / 'p2017_afib.json', 'w', encoding='utf-8') as f:
        jdumps({'sensitivity': p2017_sens, 'specificity': p2017_spec}, f, indent=2)
else: print("PhysioNet 2017 not found.")

# 2. CUDB (VT Validation)
cudb_path = DATASET_PATHS['cudb']
if os.path.isdir(cudb_path):
    vt_detected = 0; vt_total = 0
    for hf in sorted(glob.glob(os.path.join(cudb_path, '*.hea')))[:10]:
        rec_id = os.path.splitext(os.path.basename(hf))[0]
        try:
            rec = wfdb.rdrecord(os.path.join(cudb_path, rec_id))
            ann = wfdb.rdann(os.path.join(cudb_path, rec_id), 'atr')
            sig = preprocess_signal(rec.p_signal[:, 0], rec.fs)
            # Mark V beats
            bc = [2 if s == 'V' else 0 for s in ann.symbol]
            rr_ms = np.diff(ann.sample) / rec.fs * 1000
            res = clinical_event_engine(rr_ms, bc)
            # CUDB is all VT/VF, so any detection is a hit
            vt_total += 1
            if res['vt']: vt_detected += 1
        except: pass
    print(f"CUDB VT Detection: {vt_detected}/{vt_total} records triggered VT rule")
    with open(ROOT_OUT / '08_engine_eval' / 'cudb_vt.json', 'w', encoding='utf-8') as f:
        jdumps({'detected': vt_detected, 'total': vt_total}, f, indent=2)
else: print("CUDB not found.")

# 3. LTAFDB (AFib sustained-detection stress test)
ltafdb_path = DATASET_PATHS['ltafdb']
if os.path.isdir(ltafdb_path):
    ltafdb_records = [os.path.splitext(os.path.basename(f))[0] for f in sorted(glob.glob(os.path.join(ltafdb_path, '*.hea')))]
    ltafdb_afib_detected = 0; ltafdb_total = 0
    for rid in ltafdb_records[:20]:  # Sample 20 long-term records
        try:
            rec = wfdb.rdrecord(os.path.join(ltafdb_path, rid))
            # Use channel 0
            sig = preprocess_signal(rec.p_signal[:, 0], rec.fs)
            peaks = detect_rpeaks(sig)
            if len(peaks) < 30: continue
            rr_ms = np.diff(peaks) / 250.0 * 1000
            bc = [0] * len(rr_ms)
            res = clinical_event_engine(rr_ms, bc)
            ltafdb_total += 1
            if res['afib']: ltafdb_afib_detected += 1
        except: pass
    print(f"LTAFDB AFib (sustained): {ltafdb_afib_detected}/{ltafdb_total} records triggered AFib")
    with open(ROOT_OUT / '08_engine_eval' / 'ltafdb_afib.json', 'w', encoding='utf-8') as f:
        jdumps({'detected': ltafdb_afib_detected, 'total': ltafdb_total}, f, indent=2)
else: print("LTAFDB not found.")

# 4. NSTDB (NLMS DSP SNR validation)
nstdb_path = DATASET_PATHS['nstdb']
if os.path.isdir(nstdb_path):
    # NSTDB contains records 118e00, 118e06, 118e12, 119e00, etc. (MIT-BIH 118/119 + calibrated noise)
    # And baseline records em (electrode motion), bw (baseline wander), ma (muscle artifact)
    nstdb_snr_results = {}
    for noise_type in ['em', 'bw', 'ma']:
        noise_file = os.path.join(nstdb_path, noise_type)
        if not os.path.isfile(noise_file + '.dat'): continue
        try:
            # Load noise record
            noise_rec = wfdb.rdrecord(noise_file)
            noise_sig = noise_rec.p_signal[:, 0]
            
            # Simple NLMS simulation: use noise as reference, measure power reduction
            # (Full NLMS requires IMU reference; here we simulate with the noise signal itself)
            L = 32  # Filter length
            mu = 0.01  # Step size
            w = np.zeros(L)
            y_clean = np.zeros(len(noise_sig))
            for i in range(L, len(noise_sig)):
                x = noise_sig[i-L:i]
                d = noise_sig[i]
                y = np.dot(w, x)
                e = d - y
                w = w + mu * e * x
                y_clean[i] = e  # Error signal = cleaned output
            
            # Compute SNR before and after (first 10000 samples)
            seg_orig = noise_sig[:10000]
            seg_clean = y_clean[:10000]
            snr_before = 10 * np.log10(np.var(seg_orig) / max(np.var(seg_orig - seg_clean), 1e-8))
            snr_after = 10 * np.log10(np.var(seg_clean) / max(np.var(seg_orig - seg_clean), 1e-8))
            nstdb_snr_results[noise_type] = {
                'snr_before_db': float(snr_before),
                'snr_after_db': float(snr_after),
                'improvement_db': float(snr_after - snr_before)
            }
            print(f"NSTDB {noise_type.upper()}: SNR {snr_before:.2f} -> {snr_after:.2f} dB (improvement: {snr_after-snr_before:.2f} dB)")
        except Exception as e:
            print(f"  NSTDB {noise_type}: failed - {e}")
    
    if nstdb_snr_results:
        with open(ROOT_OUT / '08_engine_eval' / 'nstdb_nlms.json', 'w', encoding='utf-8') as f:
            jdumps(nstdb_snr_results, f, indent=2)
else: print("NSTDB not found.")

print("Clinical Engine Validation Complete.")
# Out:
# PhysioNet 2017 not found.
# CUDB VT Detection: 0/10 records triggered VT rule
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# LTAFDB AFib (sustained): 17/20 records triggered AFib
# NSTDB EM: SNR 0.11 -> -17.90 dB (improvement: -18.01 dB)
# NSTDB BW: SNR 0.02 -> -24.47 dB (improvement: -24.49 dB)
# NSTDB MA: SNR 1.33 -> -5.96 dB (improvement: -7.29 dB)
# Clinical Engine Validation Complete.

# %% [markdown]
# ## 11. Firmware Export & Quantization
#
# **Constraint 6:** Export models with honest size reporting (~26KB raw, ~71KB total flash footprint).

# %%
# ── Section 11: Firmware Export ──────────────────────────────────────────────
def representative_dataset(n=500):
    idx = np.random.default_rng(SEED).choice(len(X_train_bal), size=min(n, len(X_train_bal)), replace=False)
    for i in idx:
        yield {'ecg_input': X_train_bal[i:i+1].astype(np.float32), 'rr_input': X_rr_train_bal[i:i+1].astype(np.float32)}

def quantize_model(model, name):
    conv = tf.lite.TFLiteConverter.from_keras_model(model)
    conv.optimizations = [tf.lite.Optimize.DEFAULT]
    conv.representative_dataset = representative_dataset
    conv.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
    conv.inference_input_type = tf.int8; conv.inference_output_type = tf.int8
    tflite_model = conv.convert()
    out_path = ROOT_OUT / '05_models_tflite' / f'{name}_int8.tflite'
    with open(out_path, 'wb') as f: f.write(tflite_model)
    return out_path, len(tflite_model)

gate_path, gate_size = quantize_model(gate_model, 'gate')
sv_path, sv_size = quantize_model(sv_model, 'sv_head')

def tflite_to_c_array(tflite_path, c_path, h_path, name):
    with open(tflite_path, 'rb') as f: data = f.read()
    with open(c_path, 'w', encoding='utf-8') as f:
        f.write(f'// Auto-generated by v11\nconst unsigned char {name}_model_data[] = {{\n')
        for i, b in enumerate(data):
            if i % 12 == 0: f.write('  ')
            f.write(f'0x{b:02x}, ')
            if i % 12 == 11: f.write('\n')
        f.write(f'\n}};\nconst unsigned int {name}_model_data_len = {len(data)};\n')
    with open(h_path, 'w', encoding='utf-8') as f:
        f.write(f'#pragma once\nextern const unsigned char {name}_model_data[];\nextern const unsigned int {name}_model_data_len;\n')

tflite_to_c_array(gate_path, ROOT_OUT/'09_firmware_export'/'gate_model_data.cc', ROOT_OUT/'09_firmware_export'/'gate_model_data.h', 'gate')
tflite_to_c_array(sv_path, ROOT_OUT/'09_firmware_export'/'sv_head_model_data.cc', ROOT_OUT/'09_firmware_export'/'sv_head_model_data.h', 'sv_head')

# Save thresholds + scaler
with open(ROOT_OUT/'09_firmware_export'/'thresholds.h', 'w', encoding='utf-8') as f:
    f.write(f'#pragma once\n#define GATE_THR {best_thr["gate"]:.4f}f\n#define V_THR {best_thr["v"]:.4f}f\n#define S_THR {best_thr["s"]:.4f}f\n')
with open(ROOT_OUT/'09_firmware_export'/'rr_scaler.h', 'w', encoding='utf-8') as f:
    f.write(f'#pragma once\nconst float rr_mean[7] = {{ {",".join(str(float(x))+"f" for x in rr_scaler.mean_)} }};\nconst float rr_scale[7] = {{ {",".join(str(float(x))+"f" for x in rr_scaler.scale_)} }};\n')

print(f"Firmware Export Complete.")
print(f"  Gate Int8: {gate_size} bytes ({gate_size/1024:.1f} KB)")
print(f"  SV Int8:   {sv_size} bytes ({sv_size/1024:.1f} KB)")
print(f"  Total Raw: {(gate_size+sv_size)/1024:.1f} KB (Framework overhead adds ~45KB on flash)")
print(f"Saved to: {ROOT_OUT/'09_firmware_export'}")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\namda\AppData\Local\Temp\tmpdctl9g33\assets
# INFO:tensorflow:Assets written to: C:\Users\namda\AppData\Local\Temp\tmpdctl9g33\assets
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\namda\AppData\Local\Temp\tmphlp0uj9g\assets
# INFO:tensorflow:Assets written to: C:\Users\namda\AppData\Local\Temp\tmphlp0uj9g\assets
# Firmware Export Complete.
#   Gate Int8: 40752 bytes (39.8 KB)
#   SV Int8:   32136 bytes (31.4 KB)
#   Total Raw: 71.2 KB (Framework overhead adds ~45KB on flash)
# Saved to: artifacts\v11_leadi_runs\20260713_233009_eeb329c1\09_firmware_export

# %% [markdown]
# ## 12. Final Report

# %%
# ── Section 12: Final Report ──────────────────────────────────────────────────
total_beats = len(X_ecg)
train_beats = int(train_mask.sum())
val_beats = int(val_mask.sum())
test_beats = int(test_mask.sum())

lines = []
lines.append("# Tarang v11 Lead I Native Rebuild Report")
lines.append(f"**Run ID:** {RUN_ID}")
lines.append("")
lines.append("## 1. Data Summary")
lines.append("- Training Sources: PTB-XL (Lead I) + CPSC2018 (Lead I) ONLY")
lines.append(f"- Total Clean Beats: {total_beats} (Train: {train_beats}, Val: {val_beats}, Test: {test_beats})")
lines.append("- 5-Label System Applied")
lines.append("")
lines.append("## 2. Primary Test Metrics (Held-out Lead I)")
lines.append(f"- Macro F1: {report_primary['macro avg']['f1-score']:.4f}")
lines.append(f"- V Recall: {report_primary['V']['recall']:.4f}")
lines.append(f"- S F1: {report_primary['S']['f1-score']:.4f}")
lines.append("")
lines.append("## 3. Cross-Database Metrics")
if incart_report:
    lines.append(f"- INCART (Lead I Gen): Macro F1 = {incart_report['macro avg']['f1-score']:.4f}")
if mitdb_report:
    lines.append(f"- MIT-BIH (Lead II Legacy): Macro F1 = {mitdb_report['macro avg']['f1-score']:.4f}")
lines.append("")
lines.append("## 4. Firmware Export")
lines.append(f"- Gate Size: {gate_size/1024:.1f} KB")
lines.append(f"- SV Size: {sv_size/1024:.1f} KB")
lines.append(f"- Total Raw: {(gate_size+sv_size)/1024:.1f} KB")
lines.append("")
lines.append("## Limitations")
lines.append("- S-class is weak (structural capacity ceiling).")
lines.append("- MIT-BIH Lead II cross-check expected to drop due to lead mismatch.")
lines.append("- This is a research prototype, not a diagnostic medical device.")
report = "\n".join(lines)

with open(ROOT_OUT / "10_reports" / "FINAL_REPORT.md", "w", encoding="utf-8") as f:
    f.write(report)

print("="*80)
print("TARANG v11 LEAD I NATIVE REBUILD COMPLETE")
print("="*80)
print(report)
print(f"\nAll artifacts saved under: {ROOT_OUT}")
# Out:
# ================================================================================
# TARANG v11 LEAD I NATIVE REBUILD COMPLETE
# ================================================================================
# # Tarang v11 Lead I Native Rebuild Report
# **Run ID:** 20260713_233009_eeb329c1
#
# ## 1. Data Summary
# - Training Sources: PTB-XL (Lead I) + CPSC2018 (Lead I) ONLY
# - Total Clean Beats: 152028 (Train: 120566, Val: 16221, Test: 15241)
# - 5-Label System Applied
#
# ## 2. Primary Test Metrics (Held-out Lead I)
# - Macro F1: 0.6593
# - V Recall: 0.0000
# - S F1: 0.9782
#
# ## 3. Cross-Database Metrics
# - INCART (Lead I Gen): Macro F1 = 0.3831
# - MIT-BIH (Lead II Legacy): Macro F1 = 0.3981
#
# ## 4. Firmware Export
# - Gate Size: 39.8 KB
# - SV Size: 31.4 KB
# - Total Raw: 71.2 KB
#
# ## Limitations
# - S-class is weak (structural capacity ceiling).
# - MIT-BIH Lead II cross-check expected to drop due to lead mismatch.
# - This is a research prototype, not a diagnostic medical device.
#
# All artifacts saved under: artifacts\v11_leadi_runs\20260713_233009_eeb329c1
